# %% [markdown]
# ## ① 基本：開閉タブ（最重要・一番使う）
# <details>
# <summary>クリックして開く</summary>
#
# ここに内容を書く
#
# </details>
#
# 👉 これだけ覚えればOK
# 👉 9割これで足りる
#
# 数学ノートでの例
# <details>
# <summary>解答を見る</summary>
#
# $$
# (\mathbf{a}, \mathbf{b}) = 5
# $$
#
# </details>

# %% [markdown]
# ## ② デフォルトで開いた状態にする
# <details open>
# <summary>最初から開いている</summary>
#
# ここに内容
#
# </details>
#
# 👉 解説を最初から見せたいときに便利

# %% [markdown]
# ## ③ 見出しっぽくする（おすすめ）
# <details>
# <summary><b>▶ 証明</b></summary>
#
# 証明を書く
#
# </details>
#
# 👉 太字にすると見やすい
# 👉 教科書っぽくなる

# %% [markdown]
# ## ④ ネスト（入れ子）※結構使う
# <details>
# <summary>問題</summary>
#
# 問題文
#
# <details>
# <summary>解答</summary>
#
# 解答内容
#
# </details>
#
# </details>
#
# 👉
#
# 問題 → 解答
# 解説 → 詳細
#
# でよく使う

# %% [markdown]
# ## ⑤ 注意・補足を隠す（実用）
# <details>
# <summary>補足（クリックで表示）</summary>
#
# 細かい説明を書く
#
# </details>
#
# 👉 ノートをスッキリ保てる

# %% [markdown]
# ## ⑥ 横線＋折りたたみ（見やすい）
# ---
# <details>
# <summary>例題</summary>
#
# 内容
#
# </details>
# ---
#
# 👉 セクション分けに便利

# %% [markdown]
# ## ⑦ 絵文字でUI強化（おすすめ）
# <details>
# <summary>📌 ポイント</summary>
#
# 重要な内容
#
# </details>
# <details>
# <summary>💡 コツ</summary>
#
# 理解のコツ
#
# </details>
# <details>
# <summary>⚠ 注意</summary>
#
# 注意点
#
# </details>
#
# 👉 視認性がかなり上がる

# %% [markdown]
# ## ① 定義（青系ボックス）
# <div style="border-left: 5px solid #2196F3; background-color: #E3F2FD; padding: 10px;">
#
# <b>定義</b><br>
# ベクトルの長さは次で定義される：
#
# $$
# \|\mathbf{a}\| = \sqrt{a_1^2 + a_2^2}
# $$
#
# </div>
#
# 👉 落ち着いた「教科書っぽい」見た目

# %% [markdown]
# ## ② 定理（緑系ボックス）
# <div style="border-left: 5px solid #4CAF50; background-color: #E8F5E9; padding: 10px;">
#
# <b>定理（シュワルツの不等式）</b><br>
#
# $$
# |(\mathbf{a}, \mathbf{b})| \le \|\mathbf{a}\| \|\mathbf{b}\|
# $$
#
# </div>
#
# 👉 重要事項に使う

# %% [markdown]
# ## ③ 注意（赤系ボックス）
# <div style="border-left: 5px solid #F44336; background-color: #FFEBEE; padding: 10px;">
#
# <b>注意</b><br>
# 内積が0でも、ベクトルがゼロとは限らない（直交の可能性あり）
#
# </div>
#
# 👉 ミスしやすいポイント用

# %% [markdown]
# ## ③ 注意（赤系ボックス）
# <div style="border-left: 5px solid #F44336; background-color: #FFEBEE; padding: 10px;">
#
# <b>注意</b><br>
# 内積が0でも、ベクトルがゼロとは限らない（直交の可能性あり）
#
# </div>
#
# 👉 ミスしやすいポイント用

# %% [markdown]
# ## ⑤ 発展・メモ（グレー）
# <div style="border-left: 5px solid #9E9E9E; background-color: #F5F5F5; padding: 10px;">
#
# <b>メモ</b><br>
# この式は高次元でも成り立つ
#
# </div>

# %% [markdown]
# ## ① 引用（超よく使う）
# > これは引用です
# > 数学の説明や参考文献を書くときに使う
#
# 👉 表示：インデント＋グレー背景っぽくなる
# 👉 「教科書っぽさ」が出る

# %% [markdown]
# 数式付き引用
# > 内積は次で定義される：
# >
# > $$
# > (\mathbf{a}, \mathbf{b}) = \sum_{i=1}^{n} a_i b_i
# > $$

# %% [markdown]
# ## ② 区切り線（セクション分け）
# ---
#
# 👉 見やすさ爆上がり
# 👉 セクション切り替えに必須

# %% [markdown]
# ## ③ 強調（太字・斜体）
# **重要**
# *補足*
# ***超重要***
#
# 👉 使いすぎ注意（でも重要）

# %% [markdown]
# ## ④ コード表示（数式や定義の説明に）
# `$\mathbb{R}^n$`
#
# 👉 「記号そのもの」を説明するときに便利

# %% [markdown]
# ## ⑤ チェックリスト（学習用に神）
# - [ ] 内積を理解した
# - [ ] ノルムを理解した
# - [ ] シュワルツの不等式を理解した
#
# 👉 進捗管理にかなり便利

# %% [markdown]
# ## ⑥ 番号付きリスト（手順説明）
# 1. ベクトルを定義する
# 2. 内積を計算する
# 3. 長さを求める

# %% [markdown]
# ## ⑦ 表（比較に最強）
# | 記号 | 意味 |
# |------|------|
# | $\|\mathbf{a}\|$ | 長さ |
# | $(\mathbf{a}, \mathbf{b})$ | 内積 |
#
# 👉 一気に整理できる

# %% [markdown]
# ## ⑧ インデント（説明の階層化）
# - ベクトル
#   - 内積
#   - ノルム
#
# 👉 構造が見やすくなる

# %% [markdown]
# ## ⑨ HTMLでセンタリング（地味に便利）
# <div align="center">
#
# $$
# \|\mathbf{a}\| = \sqrt{a_1^2 + a_2^2}
# $$
#
# </div>
#
# 👉 数式を中央強調

# %% [markdown]
# ## ⑩ 折りたたみ（復習・解答）
# <details>
# <summary>解答</summary>
#
# 内容
#
# </details>
#
# 👉 これ＋色ボックスで最強

# %% [markdown]
# ## ⑪ 改行テク（地味に重要）
# 文章です
# 次の行
#
# 👉 半角スペース2つで改行

# %% [markdown]
# ## ⑫ ハイライト（HTML）
# <span style="background-color: yellow;">ここ重要</span>
#
# 👉 試験対策に便利

# %% [markdown]
# ## ⑬ 小さなメモ（控えめ）
# <small>※これは補足です</small>

# %% [markdown]
# ## ⑭ 画像＋キャプション
# ![図](image.png)
#
# *図1：ベクトルのイメージ*
